# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Session 1

# %% [markdown]
# ## Arrays in numpy
# 1. Explore how the normal arithmetic operators + and * work with arrays, and compare to np.dot. You should choose small arrays with integer spacing so that you can understand what is being done.

# %% [markdown]
# 2. Create an (8 × 8) array of zeros, and then change alternating entries to 1 using slices and steps. Plot with plt.imshow: you should see columns of colour.

# %%
arr = np.zeros((8,8))
arr[::2,::2] = 1
arr[1::2,1::2] = 1
plt.imshow(arr)

# %% [markdown]
# 3. Still setting different elements to 1, now try to create a chessboard from the array in the previous question by treating even and odd rows differently

# %% [markdown]
# ## Plotting with Matplotlib

# %%
n = np.arange(0, 1000, 1)
phi = 0.5*(1+np.sqrt(5))
r = 0.5*np.sqrt(n)
theta = 2*np.pi*n/(1+phi)

x = r*np.cos(theta)
y = r*np.sin(theta)

plt.plot(x[::2],y[::2],'o')

# %%
plt.polar(theta[::2], r[::2], 'o')

# %%
for i in range(1,5):
    plt.polar(theta[i::5], r[i::5], 'o')

# %% [markdown]
# ## Loops and control

# %%
x = np.linspace(-2, 0.6, 100)
y = np.linspace(-1.2, 1.2, 100)

result = np.zeros((100, 100))
for i, xval in enumerate(x):
    for j, yval in enumerate(y):
        iters = 0
        real = 0
        imaginary = 0
        while (np.sqrt(real**2 + imaginary**2) <= 2) and iters < 70:
            real = real**2 - imaginary**2 + xval
            imaginary = 2*real*imaginary + yval
            iters +=1
        if np.sqrt(real**2 + imaginary**2) > 2:
            result[i,j] = 1 - np.sqrt(iters/70)
plt.imshow(result)
